# %% [markdown]
# ## **การกำหนดลักษณะกราฟ**

# %%
# Load ggplot2
library(ggplot2)

# Very basic chart
basic <- ggplot( mtcars , aes(x=mpg, y=wt)) + 
  geom_point()
basic
# Out:
# plot without title

# %% [markdown]
# ### **การกำหนดชื่อแกนและลิมิตของแกน**

# %% [markdown]
# - #### **Xlab** = กำหนดชื่อแกน

# %% [markdown]
# - #### **Xlim** = กำหนดลิมิตของแกน

# %%
basic+
    xlab("mpg value") + 
    xlim(0,50)
# Out:
# plot without title

# %% [markdown]
# ### **การตกแต่งชื่อแกน**

# %% [markdown]
# - #### ใช้ฟังก์ชั่น **axis_title()**

# %%
# Left -> both axis are modified
basic + theme(axis.title = element_text( angle = 90, color="red", size=15, face=3)) # face = title location
# Right -> only the x axis is modified
basic + theme(axis.title.x = element_text( angle = 90, color="red", size=15, face=3))
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### **การตกแต่งตัวหนังสือบนแกน**

# %% [markdown]
# - #### ใช้ฟังก์ชั่น **axis_text()**

# %%
basic + 
  theme(axis.text = element_text( 
    angle = 90, 
    color="orange", 
    size=15, 
    face=3)
  )
# Out:
# plot without title

# %% [markdown]
# ### **การตกแต่งเส้นแกนและการทำเส้นประ**

# %% [markdown]
# - #### ใช้ฟัังก์ชั่น **axis_ticks() และ axis_line()**

# %%
# chart 1: ticks
basic + theme(
   axis.ticks = element_line(size = 2, color="red") , 
   axis.ticks.length = unit(.5, "cm")
)
# chart 2: axis lines
basic + theme(axis.line = element_line(size = 3, colour = "green", linetype=2))
# chart 3: combination
ggplot( mtcars , aes(x=mpg, y=wt)) + geom_point() +
    theme(
        axis.title = element_text( color="red", size=15, face=2),
        axis.line = element_line(size = 3, colour = "green", linetype=2),
        axis.text = element_text( angle = 90, color="blue", size=15, face=2)
        )
# Out:
# plot without title
# plot without title
# plot without title

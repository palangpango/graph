# %% [markdown]
# ## **Circular Scatterplot**

# %%
# Upload library
library(circlize)
circos.par("track.height" = 0.4)

# Create data
data = data.frame(
    factor = sample(letters[1:8], 1000, replace = TRUE),
    x = rnorm(1000),
    y = runif(1000)
    )

# Step1: Initialise the chart giving factor and x-axis.
circos.initialize( factors=data$factor, x=data$x )

# Step 2: Build the regions.
circos.trackPlotRegion(factors = data$factor, y = data$y, panel.fun = function(x, y) {
    circos.axis()
    })

# Step 3: Add points
circos.trackPoints(data$factor, data$x, data$y, col="#69b3a2")
# Out:
# ========================================
# circlize version 0.4.8
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: http://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
# ========================================
# plot without title

# %% [markdown]
# ## **Circular Line chart**

# %%
# Upload library
library(circlize)
circos.par("track.height" = 0.4)

# Create data
data = data.frame(
    factor = sample(letters[1:8], 1000, replace = TRUE),
    x = rnorm(1000),
    y = runif(1000)
    )

# Step1: Initialise the chart giving factor and x-axis.
circos.initialize( factors=data$factor, x=data$x )

# Step 2: Build the regions.
circos.trackPlotRegion(factors = data$factor, y = data$y, panel.fun = function(x, y) {
    circos.axis()
    })

# Step 3: Add points
circos.trackLines(data$factor, data$x[order(data$x)], data$y[order(data$x)], col = rgb(0.1,0.5,0.8,0.3), lwd=2)
# Out:
# Note: 1 point is out of plotting region in sector 'a', track '1'.
#
# Note: 2 points are out of plotting region in sector 'b', track '1'.
#
# Note: 3 points are out of plotting region in sector 'c', track '1'.
#
# Note: 1 point is out of plotting region in sector 'd', track '1'.
#
# Note: 2 points are out of plotting region in sector 'e', track '1'.
#
# Note: 2 points are out of plotting region in sector 'g', track '1'.
# plot without title

# %% [markdown]
# ## **Vertical ablines**

# %%
# Upload library
library(circlize)
circos.par("track.height" = 0.4)

# Create data
data = data.frame(
    factor = sample(letters[1:8], 1000, replace = TRUE),
    x = rnorm(1000),
    y = runif(1000)
    )

# Step1: Initialise the chart giving factor and x-axis.
circos.initialize( factors=data$factor, x=data$x )

# Step 2: Build the regions.
circos.trackPlotRegion(factors = data$factor, y = data$y, panel.fun = function(x, y) {
    circos.axis()
    })

# Step 3: Add points
circos.trackLines(data$factor, data$x[order(data$x)], data$y[order(data$x)], col = rgb(0.1,0.5,0.8,0.3), lwd=2, type="h")
# Out:
# Note: 2 points are out of plotting region in sector 'c', track '1'.
#
# Note: 2 points are out of plotting region in sector 'c', track '1'.
#
# Note: 2 points are out of plotting region in sector 'd', track '1'.
#
# Note: 2 points are out of plotting region in sector 'd', track '1'.
#
# Note: 2 points are out of plotting region in sector 'f', track '1'.
#
# Note: 2 points are out of plotting region in sector 'h', track '1'.
# plot without title

# %% [markdown]
# ## **Circular histogram**

# %%
# Upload library
library(circlize)
circos.par("track.height" = 0.4)

# Create data
data = data.frame(
    factor = sample(letters[1:8], 1000, replace = TRUE),
    x = rnorm(1000),
    y = runif(1000)
    )

# Step1: Initialise the chart giving factor and x-axis.
circos.initialize( factors=data$factor, x=data$x )

circos.trackHist(data$factor, data$x, bg.col = "white", col = "#69b3a2")
# Out:
# plot without title

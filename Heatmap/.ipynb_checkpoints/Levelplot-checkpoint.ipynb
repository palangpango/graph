# %% [markdown]
# # **LEVELPLOT()**

# %% [markdown]
# ### **การใช้ levelplot เบื้องต้น**

# %% [markdown]
# > #### Input ที่ต้องการเป็นแบบ Long format มี 3 ตัวแปร คือ x, y, value

# %%
# Load the lattice package
library("lattice")
 
# Dummy data
x <- seq(1,10, length.out=20)
y <- seq(1,10, length.out=20)
data <- expand.grid(X=x, Y=y)
data$Z <- runif(400, 0, 5)

## Try it out
levelplot(Z ~ X*Y, data=data  ,xlab="X",
          main="")
# Out:
# plot without title

# %% [markdown]
# ### **การเปลี่ยนข้อมูลให้เป็นแบบ wide format**

# %%
# Load the library
library("lattice")
 
# Dummy data
data <- matrix(runif(100, 0, 5) , 10 , 10)
colnames(data) <- letters[c(1:10)]
rownames(data) <- paste( rep("row",10) , c(1:10) , sep=" ")
 
# plot it flipping the axis
levelplot(data)
# Out:
# plot without title

# %% [markdown]
# ### **การพลิกหรือเปลี่ยนแกน**

# %% [markdown]
# > #### สามารถ transpose input โดยใช้ฟังก์ชั่น **t()**

# %%
# Load the library
library("lattice")
 
# Dummy data
data <- matrix(runif(100, 0, 5) , 10 , 10)
colnames(data) <- letters[c(1:10)]
rownames(data) <- paste( rep("row",10) , c(1:10) , sep=" ")
 
# plot it flipping the axis
levelplot( t(data[c(nrow(data):1) , ]),
           col.regions=heat.colors(100))
# Out:
# plot without title

# %% [markdown]
# ### **การกำหนดสี**

# %% [markdown]
# #### การกำหนดสีมีหลายวิธี เช่น

# %% [markdown]
# > #### 1) ใช้สีจากโปรแกรม โดยฟังก์ชั่น **terrain.color(), rainbow(), heat.colors(), topo.colors() และ cm.colors()**

# %% [markdown]
# > #### 2) ใช้สีจาก **RcolorBrewer**

# %% [markdown]
# > #### 3) ใช้สีจาก **Viridis**

# %%
# Lattice package
require(lattice)

# The volcano dataset is provided, it looks like that:
#head(volcano)

# 1: native palette from R
levelplot(volcano, col.regions = terrain.colors(100)) # try cm.colors() or terrain.colors()

# 2: Rcolorbrewer palette
library(RColorBrewer)
coul <- colorRampPalette(brewer.pal(8, "PiYG"))(25)
levelplot(volcano, col.regions = coul) # try cm.colors() or terrain.colors()

# 3: Viridis
library(viridisLite)
coul <- viridis(100)
levelplot(volcano, col.regions = coul) 
#levelplot(volcano, col.regions = magma(100))
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # **Multi Density Chart**

# %% [markdown]
# > ### **การสร้าง density chart หลายchartในแกนกราฟเดียวกัน**

# %%
# Libraries
library(ggplot2)
library(hrbrthemes)
library(dplyr)
library(tidyr)
library(viridis)

# The diamonds dataset is natively available with R.

# Without transparency (left)
p1 <- ggplot(data=diamonds, aes(x=price, group=cut, fill=cut)) +
    geom_density(adjust=1.5) +
    theme_ipsum() 
#p1

# With transparency (right)
p2 <- ggplot(data=diamonds, aes(x=price, group=cut, fill=cut)) +
    geom_density(adjust=1.5, alpha=.4) +
    theme_ipsum()
#p2

# %% [markdown]
# #### **Without transparency (ทึบแสง)**

# %%
p1
# Out:
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# plot without title

# %% [markdown]
# #### **With transparency (โปร่งแสง)**

# %%
p2
# Out:
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# plot without title

# %% [markdown]
# #### ตัวอย่างสำหรับข้อมูลชุดอื่นๆ ถ้ามีการกระจายที่ต่างกันมาก ใส่ชื่อบนกราฟเลย ดีกว่าใส่ legend ข้างๆ

# %%
# Load dataset from github
data <- read.table("https://raw.githubusercontent.com/zonination/perceptions/master/probly.csv", header=TRUE, sep=",")
data <- data %>%
  gather(key="text", value="value") %>%
  mutate(text = gsub("\\.", " ",text)) %>%
  mutate(value = round(as.numeric(value),0))

# A dataframe for annotations
annot <- data.frame(
  text = c("Almost No Chance", "About Even", "Probable", "Almost Certainly"),
  x = c(5, 53, 65, 79),
  y = c(0.15, 0.4, 0.06, 0.1)
)

# Plot
data %>%
  filter(text %in% c("Almost No Chance", "About Even", "Probable", "Almost Certainly")) %>%
  ggplot( aes(x=value, color=text, fill=text)) +
    geom_density(alpha=0.6) +
    scale_fill_viridis(discrete=TRUE) +
    scale_color_viridis(discrete=TRUE) +
    geom_text( data=annot, aes(x=x, y=y, label=text, color=text), hjust=0, size=4.5) +
    theme_ipsum() +
    theme(
      legend.position="none"
    ) +
    ylab("") +
    xlab("Assigned Probability (%)")
# Out:
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# plot without title

# %% [markdown]
# ### **Small Multiple with facet_wrap()**

# %% [markdown]
# > #### การแยกออกเป็นกราฟเล็กๆ อ่านค่าง่ายกว่า โดยแกน x ต้องเป็นแกนเดียวกัน

# %%
# Using Small multiple
ggplot(data=diamonds, aes(x=price, group=cut, fill=cut)) +
    geom_density(adjust=1.5) +
    theme_ipsum() +
    facet_wrap(~cut) +
    theme(
      legend.position="none",
      panel.spacing = unit(0.3, "lines"),
      axis.ticks.x=element_blank()
    )
# Out:
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# plot without title

# %% [markdown]
# ### **Stacked density chart**

# %% [markdown]
# >   #### แสดงเป็นกราฟซ้อนๆกัน เพื่อให้เห็นความถี่ของแต่ละชั้นข้อมูล แต่ว่าดูยากกว่าแบบอื่น

# %%
# Stacked density plot:
p <- ggplot(data=diamonds, aes(x=price, group=cut, fill=cut)) +
    geom_density(adjust=1.5, position="fill") +
    theme_ipsum()
p
# Out:
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# "font family not found in Windows font database"
# plot without title

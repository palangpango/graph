# %% [markdown]
# # **Grouped boxplot with ggplot2**

# %% [markdown]
# > #### **ใช้ตอนมีข้อมูลหลายกลุ่ม มี group และ subgroup**

# %% [markdown]
#  > #### **ใน ggplot จะเรียก group ว่า x และ subgroup ว่า fill**

# %% [markdown]
# #### ตัวอย่าง

# %% [markdown]
# #### ข้อมูลมี 7 กลุ่ม (A-G) และมีกลุ่มย่อยคือ (Low & High)

# %%
# library
library(ggplot2)
 
# create a data frame
variety=rep(LETTERS[1:7], each=40)
treatment=rep(c("high","low"),each=20)
note=seq(1:280)+sample(1:150, 280, replace=T)
data=data.frame(variety, treatment ,  note)
 
# grouped boxplot
ggplot(data, aes(x=variety, y=note, fill=treatment)) + 
    geom_boxplot()
    options(repr.plot.width  = 15, repr.plot.height = 10, repr.plot.res = 200)
# Out:
# plot without title

# %% [markdown]
# #### **สามารถแยกออกมาเป็นกราฟเล็กๆของแต่ละgroup และ subgroupได้**

# %% [markdown]
# > #### แยกกราฟตาม **subgroup**

# %%
# One box per treatment
p1 <- ggplot(data, aes(x=variety, y=note, fill=treatment)) + 
    geom_boxplot() +
    facet_wrap(~treatment)
# one box per variety
p2 <- ggplot(data, aes(x=variety, y=note, fill=treatment)) + 
    geom_boxplot() +
    facet_wrap(~variety, scale="free")
p1
# Out:
# plot without title

# %% [markdown]
# > #### แยกกราฟตาม **group**

# %%
p2
# Out:
# plot without title
